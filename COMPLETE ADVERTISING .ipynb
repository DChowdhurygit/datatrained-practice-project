# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %% [markdown]
# we have 200 rows and 5 columns in df dataset

# %%
df=pd.DataFrame(df)
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# all the datas are numeric so we dont need to apply LabelEncoder

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %% [markdown]
# These are the total columns present in df dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# there is no null value present in df dataset

# %%
df["sales"].unique()
# Out:
# array([22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#        17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. ,  5.6,
#        15.5, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,  9.5, 12.8,
#        25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7,  8.5, 14.9, 23.2, 14.8,
#        11.4, 10.7, 22.6, 21.2, 20.2, 23.7,  5.5, 23.8, 18.4,  8.1, 24.2,
#        15.7, 14. , 13.4, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 12.3, 13.6, 21.7, 15.2, 16. , 16.7, 11.2,  7.3, 19.4,
#        22.2, 11.5, 16.9, 11.7, 17.2, 19.2, 19.8, 21.8, 14.1, 12.6, 12.2,
#         9.4,  6.6,  7. , 11.6, 19.7, 24.7,  1.6, 12.7,  5.7, 19.6, 10.8,
#        20.8, 10.9, 20.1, 10.3, 16.1, 15.6,  3.2, 15.3, 14.4, 13.3,  8. ,
#         8.4, 14.5,  7.6, 27. , 26.2, 17.6, 17.3,  6.7,  9.9,  5.9, 25.5])

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %% [markdown]
# df['Unnamed'] data is integer type and rest of the columns float type

# %% [markdown]
# # EDA

# %% [markdown]
# Univariate analysis

# %% [markdown]
# CHECKING THE DISTRIBUTION OF THE FLOAT TYPE COLUMNS

# %%
sns.distplot(df["TV"])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %% [markdown]
# In df["TV"] column datas are equally distributed

# %%
sns.distplot(df["radio"])
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %% [markdown]
# In df["radio"] column datas are equally distributed

# %%
sns.distplot(df["newspaper"])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Density'>

# %% [markdown]
# In df["newspaper"] column skewness is present

# %%
sns.distplot(df["sales"])
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# In df["sales"] column datas are equally distributed

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
sns.violinplot(df['Unnamed: 0'])
# Out:
# <AxesSubplot:xlabel='Unnamed: 0'>

# %% [markdown]
# violin plot of df['Unnamed: 0']

# %% [markdown]
# Bi variate analysis

# %%
sns.scatterplot(df['sales'],df['radio'])
# Out:
# <AxesSubplot:xlabel='sales', ylabel='radio'>

# %% [markdown]
# These dots indicates the relation between df['sales']&df['radio']

# %%
sns.scatterplot(df['sales'],df['TV'])
# Out:
# <AxesSubplot:xlabel='sales', ylabel='TV'>

# %% [markdown]
# Here is the relation between the df['sales']&df['TV']

# %%
sns.scatterplot(df['sales'],df['newspaper'])
# Out:
# <AxesSubplot:xlabel='sales', ylabel='newspaper'>

# %% [markdown]
# Here is the relation between the df['sales']&df['newspaper']

# %%
sns.pairplot(df)

# %% [markdown]
# The whole pairplot of df.columns

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# The staticstical summary of df dataset.In df["newspaper"] mean is higher than median(50%),so skewness is present.Outliers might be present as there is difference between 75% and max in column df["newspaper"]

# %%
cor=df.corr()
cor
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# df['Unnamed: 0'] has negative correlation with our target variable but as there is not much columns present in the dataset so we are not dropping the column

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df.skew()
# Out:
# Unnamed: 0    0.000000
# TV           -0.069853
# radio         0.094175
# newspaper     0.894720
# sales         0.407571
# dtype: float64

# %% [markdown]
# keeping the range between +/-0.5

# %%
df['newspaper']=np.sqrt(df['newspaper'])

# %%
df.skew()
# Out:
# Unnamed: 0    0.000000
# TV           -0.069853
# radio         0.094175
# newspaper     0.062388
# sales         0.407571
# dtype: float64

# %% [markdown]
# Skewness has been reduced in df['newspaper']

# %%
df.plot(kind="box",subplots=True,layout=(2,3),figsize=(10,10))
# Out:
# Unnamed: 0       AxesSubplot(0.125,0.536818;0.227941x0.343182)
# TV            AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# radio         AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# newspaper           AxesSubplot(0.125,0.125;0.227941x0.343182)
# sales            AxesSubplot(0.398529,0.125;0.227941x0.343182)
# dtype: object

# %% [markdown]
# Outliers are not present in any columns of df dataset

# %% [markdown]
# # SEPARATING THE COLUMNS INTO FEATURES AND TARGET

# %%
features=df.drop("sales",axis=1)
target=df["sales"]

# %% [markdown]
# # scaling the data using min-max scaler

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
features=mms.fit_transform(features)
features
# Out:
# array([[0.        , 0.77578627, 0.76209677, 0.76716935],
#        [0.00502513, 0.1481231 , 0.79233871, 0.6089164 ],
#        [0.01005025, 0.0557998 , 0.92540323, 0.76776251],
#        [0.01507538, 0.50997633, 0.83266129, 0.70101267],
#        [0.0201005 , 0.60906324, 0.21774194, 0.70036702],
#        [0.02512563, 0.02705445, 0.9858871 , 0.80089314],
#        [0.03015075, 0.19208657, 0.66129032, 0.42450452],
#        [0.03517588, 0.4041258 , 0.39516129, 0.2821655 ],
#        [0.04020101, 0.02671627, 0.04233871, 0.04465017],
#        [0.04522613, 0.67331755, 0.05241935, 0.40048186],
#        [0.05025126, 0.2211701 , 0.11693548, 0.43157997],
#        [0.05527638, 0.72370646, 0.48387097, 0.14337313],
#        [0.06030151, 0.07811972, 0.70766129, 0.74734852],
#        [0.06532663, 0.32735881, 0.15322581, 0.21082871],
#        [0.07035176, 0.68785932, 0.66330645, 0.61549891],
#        [0.07537688, 0.65843761, 0.96169355, 0.66396287],
# ...

# %%
features.shape
# Out:
# (200, 4)

# %% [markdown]
# THERE ARE 200 ROWS AND 4 COLUMNS

# %%
target.shape
# Out:
# (200,)

# %% [markdown]
# there are 200 rows and 1 columns in target columns

# %% [markdown]
# # APPLYING VARIOUS MODEL

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=22)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.9176934921597688

# %% [markdown]
# # SUPPORT VECTOR REGRESSOR

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(features_train,target_train)
pred_test=svr.predict(features_test)
print(r2_score(target_test,pred_test))
# Out:
# 0.8849283502688238

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(features_train,target_train)
pred_test=dtr.predict(features_test)
print(r2_score(target_test,pred_test))
# Out:
# 0.9452857630341802

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
knr.fit(features_train,target_train)
pred_test=knr.predict(features_test)
print(r2_score(target_test,pred_test))
# Out:
# 0.9136684545837046

# %% [markdown]
# # REGULARIZATION

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import Lasso 


parameters={"alpha":[.0001,.001,.01,.1,1,10],"random_state":list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'random_state': 0}

# %%
ls=Lasso(alpha=0.01,random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls=ls.predict(features_test)

lss=r2_score(target_test,pred_ls)
lss
# Out:
# 0.9178453757320924

# %% [markdown]
# # Cross validation score

# %% [markdown]
# In order to get the best model we need to check the cross validation score

# %%
print(cross_val_score(ls,features,target,cv=5).mean())
# Out:
# 0.8866401504365349

# %%
print(cross_val_score(lr,features,target,cv=5).mean())
# Out:
# 0.8845195240759566

# %%
print(cross_val_score(dtr,features,target,cv=5).mean())
# Out:
# 0.9508203595158999

# %%
print(cross_val_score(svr,features,target,cv=5).mean())
# Out:
# 0.8253819302854157

# %%
print(cross_val_score(knr,features,target,cv=5).mean())
# Out:
# 0.8886998550563806

# %% [markdown]
# # ENSEMBLE TECHNIQUE

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={"criterion":["mse","mae"],"max_features":["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion="mae",max_features="auto")

rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_rf=rf.predict(features_test)

rfs=r2_score(target_test,pred_rf)
print('R2_score:',rfs*100)


rfc=(cross_val_score(rf,features,target,cv=5).mean())
print("cross_val_score:",rfc*100)
# Out:
# R2_score: 98.25706729702061
# cross_val_score: 97.27042024789006

# %% [markdown]
# # SAVING THE BEST MODEL

# %%
import joblib
joblib.dump(rf,"advrf.obj")
# Out:
# ['advrf.obj']

# %%
loaded_model=joblib.load('advrf.obj')

# %%
result=loaded_model.score(features_test,target_test)
print(result)
# Out:
# 0.9825706729702062

# %% [markdown]
# as we can see the result is giving us 98% accuracy
