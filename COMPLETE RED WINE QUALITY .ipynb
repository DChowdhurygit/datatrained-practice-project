# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("winequality_red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# THERE ARE 1599 ROWS AND 12 COLUMNS PRESENT IN df DATASET

# %%
df=pd.DataFrame(df)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# all the datas are numeric so we dont need to apply LabelEncoder

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# These are the total columns present in our dataset. Here "quality" is our target variable and rest of the columns are independent variable

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# there is no null value present in df dataset

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# Here is the statistical summary of df dataframe. we dont observe much differences between median and mode in all the columns except "fixed acidity" column,from which we can say that there is not much skewness present in the dataset. In column "total sulfur dioxide" there is huge difference between the 75% and max

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# Univariate analysis

# %%
#countplot

# %%
sns.countplot(df["quality"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# in df["quality"] datas are not equally distributed,class imbalance issue is present which needs to be fixed

# %%
#distplot

# %%
sns.distplot(df["fixed acidity"])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %% [markdown]
# datas are equally distributed here

# %%
#histplot

# %%
sns.histplot(df["volatile acidity"],bins=20)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Count'>

# %% [markdown]
# datas are equally distributed in df["volatile acidity"

# %%
sns.histplot(df["residual sugar"],bins=20)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Count'>

# %% [markdown]
# in df["residual sugar" datas are not equally distributed

# %%
#kdeplot

# %%
sns.kdeplot(df["citric acid"])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %% [markdown]
# in df["citric acid"] skewness is not present

# %%
sns.kdeplot(df['chlorides'])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %% [markdown]
# in df['chlorides'] datas are equally distributed

# %%
#boxplot

# %%
sns.boxplot(df['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide'>

# %% [markdown]
# outliers are present in df["free sulfur dioxide"]

# %%
sns.boxplot(df['total sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide'>

# %% [markdown]
# outliers are present in df["total sulfur dioxide"]

# %%
sns.boxplot(df['density'])
# Out:
# <AxesSubplot:xlabel='density'>

# %% [markdown]
# outliers are present in df["density"]

# %% [markdown]
# # BI-VARIATE ANALYSIS

# %%
#scatter plot

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df['pH'],df['sulphates'],hue=df["quality"])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='sulphates'>

# %% [markdown]
# different color dots represent different quality

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df['fixed acidity'],df['volatile acidity'],hue=df["quality"])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='volatile acidity'>

# %% [markdown]
# different color dots represent different quality

# %%
#lineplot

# %%
sns.lineplot("citric acid","residual sugar",data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='residual sugar'>

# %% [markdown]
# here is the lineplot between "citric acid" and "residual sugar"

# %%
#regplot

# %%
sns.regplot("chlorides","alcohol",data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='alcohol'>

# %% [markdown]
# created regplot between "chlorides" and "alcohol"

# %%
#pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# here is pairplot between all the columns

# %%
cor=df.corr()
cor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# df['volatile acidity'] is negatively correated with our target variable

# %%
df.drop(['volatile acidity'],axis=1,inplace=True)

# %%
df
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      0.076
# 1               7.8         0.00             2.6      0.098
# 2               7.8         0.04             2.3      0.092
# 3              11.2         0.56             1.9      0.075
# 4               7.4         0.00             1.9      0.076
# ...             ...          ...             ...        ...
# 1594            6.2         0.08             2.0      0.090
# 1595            5.9         0.10             2.2      0.062
# 1596            6.3         0.13             2.3      0.076
# 1597            5.9         0.12             2.0      0.075
# 1598            6.0         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# ...

# %% [markdown]
# we dropped the df['volatile acidity'] as it was negatively correated with target variable

# %%
df.columns
# Out:
# Index(['fixed acidity', 'citric acid', 'residual sugar', 'chlorides',
#        'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH',
#        'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# dropped column is no longer present in df dataset

# %%
df.plot(kind="box",subplots=True,layout=(2,6),figsize=(20,20))
# Out:
# fixed acidity              AxesSubplot(0.125,0.536818;0.110714x0.343182)
# citric acid             AxesSubplot(0.257857,0.536818;0.110714x0.343182)
# residual sugar          AxesSubplot(0.390714,0.536818;0.110714x0.343182)
# chlorides               AxesSubplot(0.523571,0.536818;0.110714x0.343182)
# free sulfur dioxide     AxesSubplot(0.656429,0.536818;0.110714x0.343182)
# total sulfur dioxide    AxesSubplot(0.789286,0.536818;0.110714x0.343182)
# density                       AxesSubplot(0.125,0.125;0.110714x0.343182)
# pH                         AxesSubplot(0.257857,0.125;0.110714x0.343182)
# sulphates                  AxesSubplot(0.390714,0.125;0.110714x0.343182)
# alcohol                    AxesSubplot(0.523571,0.125;0.110714x0.343182)
# quality                    AxesSubplot(0.656429,0.125;0.110714x0.343182)
# dtype: object

# %% [markdown]
# outliers are present in all the columns,which needs to be romoved

# %% [markdown]
# # OUTLIERS REMOVAL

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.52835961, 1.39147228, 0.45321841, ..., 0.57920652, 0.96024611,
#         0.78782264],
#        [0.29854743, 1.39147228, 0.04341614, ..., 0.1289504 , 0.58477711,
#         0.78782264],
#        [0.29854743, 1.18607043, 0.16942723, ..., 0.04808883, 0.58477711,
#         0.78782264],
#        ...,
#        [1.1603431 , 0.72391627, 0.16942723, ..., 0.54204194, 0.54162988,
#         0.45084835],
#        [1.39015528, 0.77526673, 0.38227061, ..., 0.30598963, 0.20930812,
#         0.78782264],
#        [1.33270223, 1.02199944, 0.75289408, ..., 0.01092425, 0.54162988,
#         0.45084835]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   42,   43,   45,
#          57,   81,   81,   83,   86,   88,   91,   92,   95,  106,  106,
#         109,  142,  144,  147,  151,  151,  151,  151,  163,  164,  169,
#         169,  181,  226,  226,  240,  243,  244,  258,  258,  274,  281,
#         291,  324,  325,  339,  340,  347,  354,  374,  381,  391,  396,
#         396,  400,  400,  442,  442,  451,  459,  467,  480,  480,  494,
#         515,  517,  544,  554,  554,  555,  555,  557,  557,  568,  584,
#         588,  591,  595,  608,  614,  636,  639,  649,  649,  651,  652,
#         652,  652,  672,  684,  690,  692,  692,  695,  723,  730,  754,
#         776,  777,  795,  821,  832,  836,  837,  889,  899,  911,  917,
#         923,  925,  926,  982, 1017, 1018, 1043, 1051, 1051, 1071, 1074,
#        1079, 1079, 1081, 1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186,
#        1231, 1235, 1244, 1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      0.076
# 1               7.8         0.00             2.6      0.098
# 2               7.8         0.04             2.3      0.092
# 3              11.2         0.56             1.9      0.075
# 4               7.4         0.00             1.9      0.076
# ...             ...          ...             ...        ...
# 1594            6.2         0.08             2.0      0.090
# 1595            5.9         0.10             2.2      0.062
# 1596            6.3         0.13             2.3      0.076
# 1597            5.9         0.12             2.0      0.075
# 1598            6.0         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# ...

# %%
df_new.shape
# Out:
# (1458, 11)

# %%
df.shape
# Out:
# (1599, 11)

# %% [markdown]
# As the rows have been reduced so we can say that the existing outliers has been removed now

# %%
(141/1599)
# Out:
# 0.08818011257035648

# %% [markdown]
# we have lost 0.088% data so far by removing the outliers

# %%
df=df_new

# %%
df.shape
# Out:
# (1458, 11)

# %% [markdown]
# # SKEWNESS

# %%
df.skew()
# Out:
# fixed acidity           0.827264
# citric acid             0.297781
# residual sugar          2.457646
# chlorides               2.288587
# free sulfur dioxide     0.873162
# total sulfur dioxide    1.183539
# density                 0.061110
# pH                      0.109577
# sulphates               0.891997
# alcohol                 0.754976
# quality                 0.400875
# dtype: float64

# %%
df=np.sqrt(df)

# %%
df.skew()
# Out:
# fixed acidity           0.606194
# citric acid            -0.518885
# residual sugar          1.835274
# chlorides               1.333708
# free sulfur dioxide     0.322492
# total sulfur dioxide    0.558103
# density                 0.058283
# pH                      0.044938
# sulphates               0.615341
# alcohol                 0.670017
# quality                 0.223177
# dtype: float64

# %% [markdown]
# we applied above code to make equal distribution

# %%
df=np.sqrt(df)

# %%
df.skew()
# Out:
# fixed acidity           0.493776
# citric acid            -1.484939
# residual sugar          1.527833
# chlorides               0.913345
# free sulfur dioxide     0.026456
# total sulfur dioxide    0.235807
# density                 0.056870
# pH                      0.012506
# sulphates               0.479075
# alcohol                 0.628620
# quality                 0.132542
# dtype: float64

# %%
df=np.sqrt(df)

# %%
df.skew()
# Out:
# fixed acidity           0.436971
# citric acid            -2.385194
# residual sugar          1.376540
# chlorides               0.715670
# free sulfur dioxide    -0.132128
# total sulfur dioxide    0.071869
# density                 0.056163
# pH                     -0.003744
# sulphates               0.411116
# alcohol                 0.608183
# quality                 0.086605
# dtype: float64

# %% [markdown]
# we further applied the code to make the distribution even

# %%
sns.histplot(df,bins=20)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# skewness has been reduced now

# %%
x=df.iloc[:,0:-1]
x
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0          1.284263     0.000000        1.083538   0.724606
# 1          1.292742     0.000000        1.126864   0.748003
# 2          1.292742     0.668740        1.109727   0.742119
# 3          1.352547     0.930087        1.083538   0.723407
# 4          1.284263     0.000000        1.083538   0.724606
# ...             ...          ...             ...        ...
# 1594       1.256172     0.729266        1.090508   0.740083
# 1595       1.248408     0.749894        1.103577   0.706397
# 1596       1.258686     0.774895        1.109727   0.724606
# 1597       1.248408     0.767181        1.090508   0.723407
# 1598       1.251033     0.909939        1.173648   0.713279
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                1.349504              1.553942  0.999725  1.169939
# 1                1.495349              1.691451  0.999599  1.156495
# ...

# %% [markdown]
# we have 1458 rows and 10 columns in x

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       1.222845
# 1       1.222845
# 2       1.222845
# 3       1.251033
# 4       1.222845
#           ...
# 1594    1.222845
# 1595    1.251033
# 1596    1.251033
# 1597    1.222845
# 1598    1.251033
# Name: quality, Length: 1458, dtype: float64

# %%
y.shape
# Out:
# (1458,)

# %% [markdown]
# we have 1458 rows and 1 column in y

# %% [markdown]
# # SCALING

# %%
from sklearn.preprocessing import StandardScaler 
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.51643315, -3.11363541, -0.61644038, ...,  1.35412975,
#         -0.6088214 , -1.03126499],
#        [-0.24326159, -3.11363541,  0.4366841 , ..., -0.82046007,
#          0.38404065, -0.59927443],
#        [-0.24326159, -0.37191683,  0.020117  , ..., -0.38559732,
#          0.15115293, -0.59927443],
#        ...,
#        [-1.34045023,  0.06329934,  0.020117  , ...,  0.74069959,
#          0.89430936,  0.60999459],
#        [-1.67160363,  0.03167152, -0.44703156, ...,  1.75548121,
#          0.6081055 , -0.1824458 ],
#        [-1.58701516,  0.61695533,  1.57384082, ...,  0.53308207,
#          0.22980852,  0.60999459]])

# %% [markdown]
# to make all the into one scale we applied StandardScaler

# %%
df
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0          1.284263     0.000000        1.083538   0.724606
# 1          1.292742     0.000000        1.126864   0.748003
# 2          1.292742     0.668740        1.109727   0.742119
# 3          1.352547     0.930087        1.083538   0.723407
# 4          1.284263     0.000000        1.083538   0.724606
# ...             ...          ...             ...        ...
# 1594       1.256172     0.729266        1.090508   0.740083
# 1595       1.248408     0.749894        1.103577   0.706397
# 1596       1.258686     0.774895        1.109727   0.724606
# 1597       1.248408     0.767181        1.090508   0.723407
# 1598       1.251033     0.909939        1.173648   0.713279
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                1.349504              1.553942  0.999725  1.169939
# 1                1.495349              1.691451  0.999599  1.156495
# ...

# %%
x=df.iloc[:,0:-1]
x
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0          1.284263     0.000000        1.083538   0.724606
# 1          1.292742     0.000000        1.126864   0.748003
# 2          1.292742     0.668740        1.109727   0.742119
# 3          1.352547     0.930087        1.083538   0.723407
# 4          1.284263     0.000000        1.083538   0.724606
# ...             ...          ...             ...        ...
# 1594       1.256172     0.729266        1.090508   0.740083
# 1595       1.248408     0.749894        1.103577   0.706397
# 1596       1.258686     0.774895        1.109727   0.724606
# 1597       1.248408     0.767181        1.090508   0.723407
# 1598       1.251033     0.909939        1.173648   0.713279
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                1.349504              1.553942  0.999725  1.169939
# 1                1.495349              1.691451  0.999599  1.156495
# ...

# %%
x.columns
# Out:
# Index(['fixed acidity', 'citric acid', 'residual sugar', 'chlorides',
#        'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH',
#        'sulphates', 'alcohol'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['fixed acidity', 'citric acid', 'residual sugar', 'chlorides',
#        'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH',
#        'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x.shape
# Out:
# (1458, 10)

# %%
x.shape[1]
# Out:
# 10

# %%
y.shape
# Out:
# (1458,)

# %%
x.columns
# Out:
# Index(['fixed acidity', 'citric acid', 'residual sugar', 'chlorides',
#        'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH',
#        'sulphates', 'alcohol'],
#       dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['variables']=x.columns
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range (x.shape[1])]
    return(vif)

# %%
calc_vif(x)
# Out:
#               variables     VIF FACTOR
# 0         fixed acidity    4610.839457
# 1           citric acid      14.470200
# 2        residual sugar     853.216430
# 3             chlorides    1380.432815
# 4   free sulfur dioxide     402.546675
# 5  total sulfur dioxide     421.039587
# 6               density  114732.791081
# 7                    pH   82988.473264
# 8             sulphates    1955.928346
# 9               alcohol    9610.720990

# %% [markdown]
# Here 'density' and 'ph' column are highly correlated but 'density' has lesser value so we need to drop it

# %%
df.drop(["density"],axis=1,inplace=True)
df
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0          1.284263     0.000000        1.083538   0.724606
# 1          1.292742     0.000000        1.126864   0.748003
# 2          1.292742     0.668740        1.109727   0.742119
# 3          1.352547     0.930087        1.083538   0.723407
# 4          1.284263     0.000000        1.083538   0.724606
# ...             ...          ...             ...        ...
# 1594       1.256172     0.729266        1.090508   0.740083
# 1595       1.248408     0.749894        1.103577   0.706397
# 1596       1.258686     0.774895        1.109727   0.724606
# 1597       1.248408     0.767181        1.090508   0.723407
# 1598       1.251033     0.909939        1.173648   0.713279
#
#       free sulfur dioxide  total sulfur dioxide        pH  sulphates  \
# 0                1.349504              1.553942  1.169939   0.930087
# 1                1.495349              1.691451  1.156495   0.952936
# ...

# %%
calc_vif(x)
# Out:
#               variables     VIF FACTOR
# 0         fixed acidity    4610.839457
# 1           citric acid      14.470200
# 2        residual sugar     853.216430
# 3             chlorides    1380.432815
# 4   free sulfur dioxide     402.546675
# 5  total sulfur dioxide     421.039587
# 6               density  114732.791081
# 7                    pH   82988.473264
# 8             sulphates    1955.928346
# 9               alcohol    9610.720990

# %% [markdown]
# # APPLYING VARIOUS MODEL

# %% [markdown]
# # LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)

lr.score(x_train,y_train)
# Out:
# 0.34591745914885197

# %%
lr.coef_
# Out:
# array([ 0.00142105,  0.00087906,  0.00036374, -0.00061331,  0.00255819,
#        -0.00418123, -0.00083877, -0.00200026,  0.00569684,  0.00746318])

# %%
lr.intercept_
# Out:
# 1.2409777223903753

# %%
pred=lr.predict(x_test)
print("predicted result price:",pred)
print("actual price:",y_test)
# Out:
# predicted result price: [1.25143144 1.24193919 1.25064135 1.22658013 1.2490079  1.22718695
#  1.2328892  1.24115279 1.22388298 1.25496816 1.26368333 1.22609476
#  1.24434419 1.25653917 1.25716874 1.22776753 1.25897657 1.23068408
#  1.24772695 1.2343326  1.22398558 1.24307997 1.24616613 1.22682654
#  1.23166955 1.23579195 1.23082062 1.25168801 1.23587669 1.24337268
#  1.26075187 1.23199448 1.23455651 1.22319738 1.24229158 1.23672502
#  1.22933687 1.22780302 1.25108678 1.26162577 1.24476152 1.25382282
#  1.24294643 1.23655284 1.22868829 1.25125626 1.22609476 1.26027404
#  1.24619525 1.23849944 1.24192733 1.22917701 1.25140998 1.24262631
#  1.22708549 1.22283729 1.24448814 1.24110966 1.22749284 1.24606774
#  1.25878623 1.25130321 1.24968136 1.23764542 1.2239182  1.23687178
#  1.26488695 1.26258377 1.25923027 1.24027129 1.24982243 1.23324328
#  1.28003982 1.22228793 1.2217299  1.23711577 1.23766415 1.23535097
#  1.23283835 1.25864239 1.24511485 1.22277616 1.22844588 1.22654501
# ...

# %%
print("error")
print(mean_squared_error(y_test,pred))
# Out:
# error
# 0.0003379022191412881

# %%
print(r2_score(y_test,pred))
# Out:
# 0.35511427850860233

# %% [markdown]
# # Lasso & Ridge Regression

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls = Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.3453823703029557

# %%
pred=ls.predict(x_test)
print("predicted result price:",pred)
print("actual price:",y_test)
# Out:
# predicted result price: [1.25096288 1.24184018 1.25047996 1.22730605 1.24885426 1.22755439
#  1.2328175  1.2410792  1.22477912 1.25508255 1.26305441 1.22643956
#  1.24434862 1.25752196 1.25641061 1.22832958 1.25787085 1.23079533
#  1.24781248 1.23491653 1.22492449 1.24325333 1.24653065 1.22718962
#  1.23175877 1.23581686 1.23113532 1.25188842 1.23589701 1.24352139
#  1.26024583 1.23224167 1.23512405 1.22457177 1.24027195 1.23684483
#  1.22920397 1.22816733 1.25091256 1.26153399 1.24428853 1.25350956
#  1.24238405 1.23517994 1.22911659 1.25052646 1.22643956 1.26095921
#  1.24653374 1.23861825 1.24230562 1.22903891 1.25134614 1.24362241
#  1.22738023 1.22300945 1.24457324 1.24122687 1.22761177 1.24643536
#  1.25851371 1.25045014 1.24988251 1.23732821 1.22415035 1.23673796
#  1.26413583 1.26174535 1.25900534 1.240252   1.24941258 1.23356502
#  1.27977802 1.22290734 1.22103763 1.23666873 1.23835408 1.23520322
#  1.23268369 1.25763577 1.24521616 1.22303899 1.22864457 1.22751952
# ...

# %%
print("error")
print(mean_squared_error(pred,y_test))
# Out:
# error
# 0.0003388424518042439

# %%
print(r2_score(y_test,pred))
# Out:
# 0.35331984631824587

# %%
ls.coef_
# Out:
# array([ 0.00082888,  0.00078575,  0.        , -0.00056528,  0.00210536,
#        -0.00372675, -0.00010473, -0.0021612 ,  0.00554916,  0.00789373])

# %%
ls.intercept_
# Out:
# 1.2409778643105096

# %%
#Ridge

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.3459174591488473

# %%
pred=ls.predict(x_test)
print("predicted result price:",pred)
print("actual price:",y_test)
# Out:
# predicted result price: [1.25096288 1.24184018 1.25047996 1.22730605 1.24885426 1.22755439
#  1.2328175  1.2410792  1.22477912 1.25508255 1.26305441 1.22643956
#  1.24434862 1.25752196 1.25641061 1.22832958 1.25787085 1.23079533
#  1.24781248 1.23491653 1.22492449 1.24325333 1.24653065 1.22718962
#  1.23175877 1.23581686 1.23113532 1.25188842 1.23589701 1.24352139
#  1.26024583 1.23224167 1.23512405 1.22457177 1.24027195 1.23684483
#  1.22920397 1.22816733 1.25091256 1.26153399 1.24428853 1.25350956
#  1.24238405 1.23517994 1.22911659 1.25052646 1.22643956 1.26095921
#  1.24653374 1.23861825 1.24230562 1.22903891 1.25134614 1.24362241
#  1.22738023 1.22300945 1.24457324 1.24122687 1.22761177 1.24643536
#  1.25851371 1.25045014 1.24988251 1.23732821 1.22415035 1.23673796
#  1.26413583 1.26174535 1.25900534 1.240252   1.24941258 1.23356502
#  1.27977802 1.22290734 1.22103763 1.23666873 1.23835408 1.23520322
#  1.23268369 1.25763577 1.24521616 1.22303899 1.22864457 1.22751952
# ...

# %%
print("error")
print(mean_squared_error(pred,y_test))
# Out:
# error
# 0.0003388424518042439

# %%
print(r2_score(y_test,pred))
# Out:
# 0.35331984631824587

# %%
rd.coef_
# Out:
# array([ 0.00142105,  0.00087906,  0.00036374, -0.00061331,  0.00255819,
#        -0.00418123, -0.00083878, -0.00200026,  0.00569684,  0.00746318])

# %%
rd.intercept_
# Out:
# 1.2409777223792182

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(random_state=0)
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
pred=dtr.predict(x_test)
print("predicted result price:",pred)
print("actual price:",y_test)
# Out:
# predicted result price: [1.22284454 1.22284454 1.2510334  1.18920712 1.2510334  1.22284454
#  1.22284454 1.2510334  1.2510334  1.27537311 1.27537311 1.22284454
#  1.22284454 1.27537311 1.27537311 1.22284454 1.2510334  1.22284454
#  1.22284454 1.22284454 1.2510334  1.2510334  1.2510334  1.2510334
#  1.2510334  1.22284454 1.22284454 1.27537311 1.18920712 1.22284454
#  1.27537311 1.22284454 1.22284454 1.22284454 1.27537311 1.2510334
#  1.22284454 1.22284454 1.27537311 1.27537311 1.2510334  1.2510334
#  1.2510334  1.2510334  1.22284454 1.2510334  1.22284454 1.2510334
#  1.2510334  1.2510334  1.22284454 1.2510334  1.2510334  1.18920712
#  1.2510334  1.18920712 1.22284454 1.2510334  1.2510334  1.22284454
#  1.2510334  1.22284454 1.22284454 1.22284454 1.22284454 1.22284454
#  1.2510334  1.27537311 1.2510334  1.2510334  1.22284454 1.2510334
#  1.29683955 1.22284454 1.22284454 1.2510334  1.22284454 1.18920712
#  1.22284454 1.2510334  1.22284454 1.22284454 1.22284454 1.22284454
# ...

# %%
print("error")
print(mean_squared_error(pred,y_test))
# Out:
# error
# 0.0004923189560638043

# %%
print(r2_score(y_test,pred))
# Out:
# 0.060410239412055144

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
# Out:
# -0.01173689318487714

# %%
pred=svr.predict(x_test)
print("predicted result price:",pred)
print("actual price:",y_test)
# Out:
# predicted result price: [1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
#  1.24302333 1.24302333 1.24302333 1.24302333 1.24302333 1.24302333
# ...

# %%
print("error")
print(mean_squared_error(pred,y_test))
# Out:
# error
# 0.0005341475175737898

# %%
print(r2_score(y_test,pred))
# Out:
# -0.01941948806610405

# %% [markdown]
# # Cross validation score

# %% [markdown]
# To get the best model we need to check the cross validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(lr,x,y,cv=5).mean())
# Out:
# 0.2957079229981826

# %%
print(cross_val_score(ls,x,y,cv=5).mean())
# Out:
# 0.16390091620684402

# %%
print(cross_val_score(rd,x,y,cv=5).mean())
# Out:
# 0.2939523501776903

# %%
print(cross_val_score(dtr,x,y,cv=5).mean())
# Out:
# -0.45595127956103154

# %%
print(cross_val_score(svr,x,y,cv=5).mean())
# Out:
# -0.061675050125407395

# %% [markdown]
# dtr(DecisionTreeRegressor) is providing the best result as there is less difference between cross validation score with the prdicted score

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={"max_depth" : np.arange(2,10),
           "criterion" :["mse","entropy"],
           "splitter":["best","random"],
           "max_features":["auto","sqrt","log2"]}

# %%
GCV=GridSearchCV(DecisionTreeRegressor(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['mse', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 3,
#  'max_features': 'auto',
#  'splitter': 'best'}

# %%
final_mod=DecisionTreeRegressor(criterion='mse',max_depth=3,max_features='auto',splitter='best')
final_mod.fit(x_train,y_train)
sc=final_mod.score(x_train,y_train)

# %%
print(sc*100)
# Out:
# 32.42543834489185

# %% [markdown]
# the accuracy score is 32.42% by using hyperparameter tuning in DecisionTreeRegressor model

# %% [markdown]
# # SAVING THE BEST MODEL

# %%
import joblib
joblib.dump(dtr,"best_dtrfile2.obj")
# Out:
# ['best_dtrfile2.obj']
